# %%
# Import the modules you need
import matplotlib.pyplot as plt
from scipy import stats

# %%
# Create the arrays that represent the values of the x and y axis
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

# %%
# Draw a scatter plot y versus x
plt.scatter(x, y)
plt.title('Nube de puntos')
plt.ylabel('')
plt.xlabel('Número de cigarrillos')
plt.show()

# %%
# Execute a method that returns some important key values of Linear Regression
slope, intercept, r, p, std_err = stats.linregress(x, y)
print ("slope =", slope, "\nIntercept =", intercept)
print('El valor del coeficiente de correlación R^2 es:'+ str(round(r**2,2)))
# Create a function that uses the slope and intercept values to return a new value
# This new value represents where on the y-axis the corresponding x value will be placed
def myfunc(x):
  return slope * x + intercept

# Run each value of the x array through the function. This will result in a new array with new values for the y-axis
mymodel = list(map(myfunc, x))
# Out:
# slope = -1.7512877115526118
# Intercept = 103.10596026490066
# El valor del coeficiente de correlación R^2 es:0.58

# %%
"""
Each line execute the following actions:
1. Draw the original scatter plot
2. Draw the line of linear regression
3. Display the diagram
"""
plt.scatter(x, y)
plt.title('Nube de puntos con línea de regresión lineal')
plt.ylabel('')
plt.xlabel('Número de cigarrillos')
plt.plot(x, mymodel)
plt.show()

# %%
x
# Out:
# [5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
import pandas as pd 

Data = pd.DataFrame(
    {'y':y,
    'Numero cigarrillos':x}
)
print(Data)
# Out:
#       y  Numero cigarrillos
# 0    99                   5
# 1    86                   7
# 2    87                   8
# 3    88                   7
# 4   111                   2
# 5    86                  17
# 6   103                   2
# 7    87                   9
# 8    94                   4
# 9    78                  11
# 10   77                  12
# 11   85                   9
# 12   86                   6

# %%
plt = sns.regplot(data = Data ,x='Numero cigarrillos',y='y')
plt = plt.set(title='Nube de puntos con recta de regresión',xlabel='Número de cigarrillos',ylabel='No me acuerdo')
