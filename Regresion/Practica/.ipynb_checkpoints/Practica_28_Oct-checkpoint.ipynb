# %% [markdown]
# # PRÁCTICA 1. APRENDIZAJE AUTOMÁTICO
# ## Viernes 28 de Octubre de 20222
#
# Vamos a replicar los ejercicios resueltos del tema 4 para ver la comparación.

# %% [markdown]
# ### EJERCICIO 4.1
# Escribir un programa que muestre por pantalla la cadena 'Hola mundo'.

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
print("Hola, me aburro")
# Out:
# Hola, me aburro

# %% [markdown]
# #### EJERCICIO 4.2:
# Escribir un programa que almacene la cadena ¡Hola mundo! en una variable H y luego muestre por pantalla el contenido de la variable

# %%
saludo = '¡Hola mundo!'
print(saludo)

# %%
#%% EJERCICIO 4.3:
# Escribir un programa que, dado el área de un cuadrado, calcule la longitud 
# de sus lados

print('='*60)

area = 10

import math
lado = math.sqrt( area )

print('El lado mide ' + str(lado) + ' m')
print('='*60)

#%% EJERCICIO 4.4:
# Escribir un programa que, dadas las longitudes L1, L2 y L3 de los lados de
# un triángulo, calcule el área del mismo

print('='*60)

a, b, c = 5, 4, 5
s = ( a + b + c ) / 2

import math

area = math.sqrt( s*(s-a)*(s-b)*(s-c) )

print('El área del triángulo es ' + str(area) + ' cm2')
print('='*60)

#%% EJERCICIO 4.5:
# Escribir un programa que pregunte el año de nacimiento al usuario en la 
# consola y después de que el usuario lo introduzca muestre por pantalla su
# edad.

print('='*60)

year = input('Introduzca el año de su nacimiento:')

print('Su edad es ' + str(2022-int(year)))
print('='*60)

#%% EJERCICIO 4.6:
# Escribir un programa que calcule el resultado de la siguiente operación
# aritmética: ( ( 3 + 2 ) / ( 2 * 5 ) ) ^ 2 y lo escriba por pantalla con el
# siguiente mensaje: 'El resultado de la operación es... '

print('='*60)
print('El resultado es ' + str( ( ( 3 + 2 ) / ( 2 * 5 ) ) ** 2 ))
print('='*60)

#%% EJERCICIO 4.7:
# Escribir un programa que, dado un número natural N, calcule la suma de todos
# los naturales hasta N. Esta suma sigue la formula (N+1)*N/2

print('='*60)

N = int(input('Introduzca N: '))

S1 = (N+1) * N / 2                      # Con la expresión de la suma

S2 = 0
for i in range(N+1):                    # Con un bucle FOR
    S2 += i

S3 = sum( [i for i in range(N+1)] )     # Con una comprehension list

print(S1)   
print(S2)
print(S3)

print('='*60)

#%% EJERCICIO 4.8:
# Escribir un programa que pregunte al usuario por el número de horas
# trabajadas y el coste por hora. Después debe mostrar por pantalla la paga que
# le corresponde.

print('='*60)
horas           = int(input('Introduzca el número de horas: '))
sueldo_por_hora = int(input('Introduzca el salario por hora: '))

print('Su sueldo es de ' + str(int(horas)*sueldo_por_hora) + '. Sin impuestos')
print('='*60)

#%% EJERCICIO 4.9:
# Escribir un programa que pida al usuario su peso (en kg) y estatura (en m),
# calcule el índice de masa corporal y lo almacene en una variable, y muestre
# por pantalla la frase "Tu índice de masa corporal es IMC", donde IMC es el 
# índice de masa corporal calculado redondeado con dos decimales.



#%% EJERCICIO 4.10:
# Escribir un programa que pida al usuario su peso (en kg) y estatura (en m),
# y el programa le devuelva cuánto peso puede ganar garantizando un IMC 
# saludable (por debajo de 24.9)

print('='*60)

masa   = float(input('Introduzca su peso (kg): '))
altura = float(input('Introduzca su altura (m): '))

IMC_maximo = 24.90
IMC_actual = float(masa) / float(altura) ** 2

margen_IMC  = IMC_maximo - IMC_actual
margen_masa = margen_IMC * float(altura) ** 2


print('Todavía puedes engordar ' + str(round(margen_masa,2)) +' kg más.')
print('='*60)

#%% EJERCICIO 4.11:
# Escribir un programa que pregunte el año de nacimiento al usuario en la
# y si tiene carnet de conducir, y le responda indicando si puede conducir.

print('='*60)

year = int(input('Introduzca su año de nacimiento: '))
lic  = input('¿Tiene carnet de conducir? (si/no): ')


tiene_18_anos  = year < 2022-18

if lic=='si':
    tiene_licencia = True
else:
    tiene_licencia = False

puede_conducir = tiene_18_anos and tiene_licencia

if tiene_18_anos and tiene_licencia:
    mensaje = 'Puede conducir' 
else:
    mensaje = 'No puede conducir'

print(mensaje)
print('='*60)

#%% EJERCICIO 4.12:
# Escribir un programa que pida al usuario dos números enteros M y N y muestre
# por pantalla 'M entre M da un cociente C y un resto R", donde N y M son los
# números introducidos por el usuario, y C y R son el cociente y el resto
# de la división entera respectivamente.

print('='*60)

M = int(input('Introduzca el primer entero: '))
N = int(input('Introduzca el segundo entero: '))

mensaje = str(M) + ' entre ' + str(N) + ' da un cociente ' + str(M//N) + ' y un resto ' + str(M%N)

print(mensaje)
print('='*60)

#%% EJERCICIO 4.13:
# Escribir un programa que pregunte al usuario una cantidad a invertir, el
# interés anual y el número de años, y muestre por pantalla el capital obtenido
# en la inversión.

print('='*60)

x = float(input('¿Cuánto dinero desea invertir (€)? '))
i = float(input('¿Cuál es la tasa de interés (%)? '))
t = int(input('¿Durante cuánto tiempo (años)? '))

print('Su capital será de ' + str(x * (1+t*i/100)) + ' €')

print('='*60)

#%% EJERCICIO 4.14:
# Escribir un programa que pida al usuario su peso (en kg) y estatura (en m),
# y devuelva una frase indicando si el usuario está en el rango saludable
# (entre 18.5 y 24.9) o no.

print('='*60)

masa   = float(input('Introduzca su peso (kg): '))
altura = float(input('Introduzca su altura (m): '))

IMC = masa / altura ** 2

if 18.5 < IMC < 24.9:
    mensaje = 'Su peso es saludable.'
else:
    mensaje = 'Su peso no es saludable.'
    
print(mensaje)
print('='*60)

#%% EJERCICIO 4.15:
# Una empresa tiene mucho éxito en dos de sus productos: A y B. Suele hacer
# venta por correo y la empresa de logística les cobra por peso de cada paquete
# así que deben calcular el peso de los productos que saldrán en cada paquete a
# demanda. El producto A pesa 3 kg y el B pesa 2 kg. Escribir un programa que
# lea el número de productos A y B vendidos en el último pedido y calcule el
# peso total del paquete que será enviado.

print('='*60)

peso_A = 3.0
peso_B = 2.0

A_vendidos = int(input('Introduzca las ventas dle producto A: '))
B_vendidos = int(input('Introduzca las ventas dle producto B: '))

peso_total = A_vendidos*peso_A + B_vendidos * peso_B

print('El pedido pesará un total de ' + str(peso_total) +' kg.')

print('='*60)


#%% EJERCICIO 4.16:
# Imagina que acabas de abrir una nueva cuenta de ahorros que te ofrece el 4% 
# de interés al año. Estos ahorros debido a intereses, que no se cobran hasta
# finales de año, se te añaden al balance final de tu cuenta de ahorros.
# Escribir un programa que comience leyendo la cantidad de dinero depositada en
# la cuenta de ahorros, introducida por el usuario. Después el programa debe 
# calcular y mostrar por pantalla la cantidad de ahorros tras el primer, 
# segundo y tercer años. Redondear cada cantidad a dos decimales.


print('='*60)

interes = 0.04

fondos = [ float(input('Inserte los fondos de su cuenta de ahorros: ')) ]

for year in range(1,5):
    fondos.append(fondos[year-1]*(1+interes))
    print('Al final del año ' + str(year) + ' tendrá ' + str(round(fondos[year],2)) + '€')

print('='*60)

# #%% EJERCICIO 4.17:
# # Un negocio vende barras de pan a 3.49€ cada una. El pan que no es el día
# # tiene un descuento del 60%. Escribir un programa que comience leyendo el
# # número de barras vendidas que no son del día. Después el programa debe
# # mostrar el precio habitual de una barra de pan, el descuento que se le hace 
# # por no ser fresca y el coste final total.

print('='*60)

precio      = 3.49
descuento   = 0.60

ventas = int(input('¿Cuántas barras se han vendido? '))
print(' ')
print('+' + '-'*60 + '+')
print('\t' + str(ventas) + 'x\t\tBarra de pan\t' + str(ventas) + 'x' + str(precio) + '\t\t ' + str(round(precio*ventas,2)) + '€')
print('\t\t\tDescuento 60%\t\t\t\t' + '-' + str(round(descuento*precio*ventas,2))+ '€')
print(' ')
print('\tTotal' + '\t'*8 + ' ' + str(round(ventas*(precio*(1-descuento)),2))+ '€')
print(' ')
print('\t'*4 + 'Gracias por su visita')

print('+' + '-'*60 + '+')
